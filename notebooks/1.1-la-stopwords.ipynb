# %%
import pandas as pd
from collections import Counter
from string import punctuation
import re
import matplotlib.pyplot as plt 
import seaborn as sns
from src.data.cleaning import prepare

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('../data/processed/drugs.csv', usecols=['target', 'text'])

# %%
df.head(10)
# Out:
#        target                                               text
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...
# 5        ORAL  Dissolve pellets under the tongue 3-4 times da...
# 6        ORAL  2 DOSAGE AND ADMINISTRATION The recommended do...
# 7        ORAL  2 DOSAGE AND ADMINISTRATION Recommended starti...
# 8        ORAL  DOSAGE AND ADMINISTRATION Methocarbamol tablet...
# 9     TOPICAL  Directions • for itching of skin irritation, i...

# %% [markdown]
# # Split on Whitespace

# %% [markdown]
# The simplest tokenization just splits on whitespace. Let's try this and explore the results.

# %%
pipeline = [str.lower, str.split]

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df.head()
# Out:
#        target                                               text  \
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...
#
#                                               tokens
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...

# %%
# create list of all tokens
all_tokens = []
df['tokens'].apply(lambda x: all_tokens.extend(x))
print(len(all_tokens))
# Out:
# 24421689

# %%
token_counts = Counter(all_tokens)

# %%
types = token_counts.keys()

# %%
print("Splitting on whitespace yields {0} tokens and {1} types.".format(token_counts.total(), len(types)))
# Out:
# Splitting on whitespace yields 24421689 tokens and 64199 types.

# %%
token_counts.most_common(50)
# Out:
# [('the', 848539),
#  ('of', 767461),
#  ('to', 633474),
#  ('and', 575946),
#  ('in', 429288),
#  ('for', 368782),
#  ('a', 364693),
#  ('be', 332645),
#  ('mg', 325358),
#  ('or', 316398),
#  ('with', 314044),
#  ('dose', 312722),
#  ('is', 274128),
#  ('patients', 241160),
#  ('should', 200433),
#  ('dosage', 196400),
#  ('not', 180881),
#  ('daily', 147990),
#  ('2', 147436),
#  ('may', 143369),
#  ('as', 141416),
#  ('tablets', 136213),
#  ('use', 120618),
#  ('at', 119581),
#  ('recommended', 115267),
#  ('(', 107298),
#  ('by', 98786),
#  ('on', 96178),
#  ('than', 92008),
#  ('every', 90687),
#  ('treatment', 89119),
#  ('if', 88270),
#  ('once', 87857),
#  ('1', 86486),
#  ('years', 86239),
#  ('hours', 84855),
#  ('administration', 82274),
#  ('12', 80998),
#  ('10', 78751),
#  ('doses', 76240),
#  ('children', 75587),
#  ('after', 75287),
#  ('are', 74859),
#  ('clinical', 74403),
#  ('day', 72896),
#  ('4', 70393),
#  (')', 70256),
#  ('•', 68949),
#  ('[see', 67200),
#  ('5', 63663)]

# %% [markdown]
# The top 30 typtes contain many stopwords. A few of them contain punctuation.

# %% [markdown]
# Let's look for other types containing punctuation.

# %%
punct_set = set(punctuation)

# %%
def contains_punct(text):
    for char in text:
        if char in punct_set:
            return True
    return False

# %%
types_with_punct = {t: count for t, count in token_counts.items() if contains_punct(t)}

# %%
types_with_punct = sorted(types_with_punct.items(), key=lambda item: item[1], reverse=True)

# %%
types_with_punct[:50]
# Out:
# [('(', 107298),
#  (')', 70256),
#  ('[see', 67200),
#  ('mg/day', 45567),
#  ('.', 43985),
#  ('2.1', 37047),
#  ('daily.', 36155),
#  ('2.2', 33025),
#  ('mg/kg', 32145),
#  (',', 31335),
#  ('extended-release', 28900),
#  ('(see', 27689),
#  (').', 24251),
#  ('2.5', 24191),
#  ('2.3', 24170),
#  ('day.', 21962),
#  (']', 19886),
#  ('].', 19498),
#  ('dose.', 18605),
#  ('2.4', 18528),
#  ('days.', 17314),
#  ('hours.', 15769),
#  (')]', 15036),
#  ('-', 14972),
#  ('mg/kg/day', 13261),
#  ('injection,', 13092),
#  ('tablets,', 12753),
#  ('(e.g.,', 12019),
#  ('mg,', 11707),
#  ('delayed-release', 11700),
#  ('dose,', 11573),
#  ('age:', 11570),
#  ('daily,', 11496),
#  ('patients,', 11068),
#  ('mg.', 10714),
#  ('however,', 10578),
#  ('and/or', 10309),
#  ('doses.', 10272),
#  (')].', 10141),
#  ('mg/m', 10133),
#  ('day,', 9997),
#  ('therapy.', 9587),
#  ('mg/day.', 9445),
#  ('hours,', 9309),
#  ('weeks.', 9253),
#  ('[', 9128),
#  ('response.', 8949),
#  ('recommended.', 8927),
#  ('patients.', 8922),
#  ('patient.', 8804)]

# %% [markdown]
# It seems fairly common for words to be combined with '/'. Let's take a look at these specifically.

# %%
[(t, count) for t, count in dict(types_with_punct).items() if '/' in t][:50]
# Out:
# [('mg/day', 45567),
#  ('mg/kg', 32145),
#  ('mg/kg/day', 13261),
#  ('and/or', 10309),
#  ('mg/m', 10133),
#  ('mg/day.', 9445),
#  ('ml/min', 8166),
#  ('mg/ml', 6093),
#  ('mg/day,', 4371),
#  ('ml/min/1.73', 3477),
#  ('mg/kg/day,', 3105),
#  ('mg/5', 3033),
#  ('mcg/kg/day', 2646),
#  ('mg/125', 2465),
#  ('ml/min)', 2321),
#  ('1/2', 2209),
#  ('ml/min,', 2067),
#  ('mcg/kg/min', 2004),
#  ('mcg/ml', 1944),
#  ('mg/kg/day.', 1941),
#  ('lopinavir/ritonavir', 1880),
#  ('mg/day)', 1837),
#  ('(ml/min)', 1778),
#  ('ml/min.', 1748),
#  ('ml/minute/1.73', 1728),
#  ('mg/day).', 1676),
#  ('atazanavir/ritonavir', 1666),
#  ('(mg/day)', 1634),
#  ('/', 1577),
#  ('/l', 1505),
#  ('mg/ml)', 1498),
#  ('mg/dl', 1447),
#  ('pharyngitis/tonsillitis', 1301),
#  ('mcg/kg', 1173),
#  ('mg/25', 1154),
#  ('ng/ml', 1059),
#  ('ml/min/1.73m', 909),
#  ('cells/mm', 891),
#  ('mg/kg)', 887),
#  ('ml/min),', 874),
#  ('mg/kg,', 857),
#  ('mcg/day', 849),
#  ('ml/minute', 840),
#  ('ml/h', 807),
#  ('caregiver/family', 791),
#  ('mg/kg.', 787),
#  ('mg/ml.', 773),
#  ('(mg/dl)', 763),
#  ('(olanzapine/fluoxetine)', 762),
#  ('mg/325', 753)]

# %% [markdown]
# Most of these represent units of measurement (e.g. 'mg/day'). However, some of them represent combinations of distinct concepts (e.g. 'caregiver/family', 'pharyngitis/tonsillitis'). Splitting on whitespace would treat these as a single token, which would add unnecessary noise to the corpus. Let's try splitting on whitespace AND on '/'.

# %% [markdown]
# # Split on Whitespace and '/'

# %%
def tokenize(text):
    pattern = re.compile(r'[\s/]')
    tokens = re.split(pattern, text)
    tokens = [t for t in tokens if t != '']
    return tokens

# %%
tokenize('mg/day foo bar')
# Out:
# ['mg', 'day', 'foo', 'bar']

# %%
pipeline = [str.lower, tokenize]

# %%
df['tokens_slash'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df.head()
# Out:
#        target                                               text  \
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...
#
#                                               tokens  \
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...
#
#                                         tokens_slash
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...

# %%
# create list of all tokens
all_tokens = []
df['tokens_slash'].apply(lambda x: all_tokens.extend(x))
print(len(all_tokens))
# Out:
# 24726907

# %%
token_counts = Counter(all_tokens)

# %%
types = token_counts.keys()

# %%
print("Splitting on whitespace and '/' yields {0} tokens and {1} types.".format(token_counts.total(), len(types)))
# Out:
# Splitting on whitespace and '/' yields 24726907 tokens and 61744 types.

# %%
token_counts.most_common(50)
# Out:
# [('the', 848539),
#  ('of', 767461),
#  ('to', 633474),
#  ('and', 586264),
#  ('mg', 485203),
#  ('in', 429291),
#  ('for', 368796),
#  ('a', 365208),
#  ('be', 332645),
#  ('or', 326760),
#  ('with', 314045),
#  ('dose', 313749),
#  ('is', 274128),
#  ('patients', 241359),
#  ('should', 200433),
#  ('dosage', 196425),
#  ('not', 180883),
#  ('2', 150658),
#  ('daily', 148068),
#  ('may', 143369),
#  ('as', 141416),
#  ('day', 138264),
#  ('tablets', 136331),
#  ('use', 120639),
#  ('at', 119581),
#  ('recommended', 115267),
#  ('(', 107300),
#  ('by', 98786),
#  ('on', 96191),
#  ('than', 92008),
#  ('every', 90694),
#  ('1', 89410),
#  ('treatment', 89176),
#  ('if', 88270),
#  ('kg', 87891),
#  ('once', 87860),
#  ('ml', 87729),
#  ('years', 86239),
#  ('hours', 84858),
#  ('administration', 82283),
#  ('12', 81025),
#  ('10', 79827),
#  ('doses', 76247),
#  ('after', 75972),
#  ('children', 75613),
#  ('are', 74859),
#  ('clinical', 74403),
#  ('4', 71042),
#  (')', 70256),
#  ('•', 68949)]

# %% [markdown]
# # Split on Whitespace and '-'

# %% [markdown]
# Some of the most common types also included '-'. Let's take a look at them.

# %%
{t: count for t, count in token_counts.items() if '-' in t}
# Out:
# {'adults-': 112,
#  'older-': 108,
#  '(one-half': 184,
#  'naproxen-containing': 202,
#  'long-term': 5254,
#  'anti-inflammatory': 815,
#  'solid-oral': 128,
#  'weight-based': 1215,
#  'one-half': 2487,
#  'non-interchangeability': 232,
#  '3-4': 1242,
#  '2-11:': 523,
#  'fda-approved': 209,
#  '(weight-adjusted': 2,
#  '-': 14985,
#  'non-cutaneous': 4,
#  '0-1,': 26,
#  'half-life': 2092,
#  'radio-isotope': 25,
#  'thyroid-pituitary': 50,
#  '26-ml': 11,
#  'back-and-forth': 58,
#  '24-hour': 4564,
#  'high-potency': 19,
#  'hypothalamic-pituitary-adrenal': 379,
#  '2-3': 1167,
#  'angiotensin-converting': 1,
#  'twice-daily.': 2,
#  'film-coated': 196,
#  'ora-plus': 491,
#  'ora-sweet': 774,
#  'press-in': 12,
#  '(child-pugh': 3218,
#  '5-10': 471,
#  '1-5': 542,
#  'well-controlled': 462,
#  'end-stage': 918,
#  'pre-': 131,
#  'high-pressure': 50,
#  '(mria-sp).': 5,
#  'cyclosporine-therapeutic': 5,
#  '50-200': 78,
#  '50-150': 11,
#  'obsessive-compulsive': 51,
#  '6-12)': 35,
#  '13-17).': 11,
#  '25-200': 11,
#  '(6-17': 11,
#  'non-intravenous': 1290,
#  '14-day': 1269,
#  '1-': 269,
#  '2-day': 64,
#  'short-': 115,
#  'long-acting': 431,
#  'beta-blockers.': 42,
#  'water-resistant': 659,
#  'long-sleeve': 1456,
#  '15-30': 158,
#  'a.m.-2': 582,
#  'long-sleeved': 2663,
#  'salt-losing': 26,
#  'short-acting': 376,
#  '-agonist': 78,
#  're-evaluated': 548,
#  'beta2-agonist': 4,
#  'otc-dosage': 78,
#  'adults~3-5': 93,
#  '2-12': 113,
#  '1-3': 759,
#  'extended-release': 28900,
#  'half-glassful': 41,
#  'per-kilogram': 68,
#  'alpha-fetoprotein': 7,
#  '5-aminolevulinate': 8,
#  '(pbg)-synthase': 8,
#  'tri-vite': 3,
#  'single-day': 268,
#  'high-dose': 447,
#  'community-acquired': 1438,
#  '(second-line': 339,
#  'non-gonococcal': 343,
#  '(5-day': 298,
#  '3-day': 273,
#  '1-day': 447,
#  '(3-day': 154,
#  '5-day': 261,
#  '(1-day': 149,
#  're-dosing': 182,
#  're-dosed': 179,
#  'once-a-day': 1439,
#  'placebo-controlled': 748,
#  'longer-term': 577,
#  'delayed-release': 11700,
#  '500-1,000': 7,
#  'once-daily': 1207,
#  '-1,125': 2,
#  '1,250-1,375': 13,
#  '1,500-1,625': 13,
#  '1,875-2,000': 13,
#  '2,125-2,250': 13,
#  '2,500-2,750': 13,
#  '3,000-3,125': 13,
#  'dose-related': 456,
#  'dose-related.': 377,
#  '-to': 1,
#  'estrogen-containing': 1857,
#  'life-threatening': 1716,
#  'half-lives,': 253,
#  'dose-escalation': 253,
#  '2-fold': 309,
#  '(pill-free': 119,
#  'pill-free': 238,
#  '2-week': 775,
#  '2-fold,': 129,
#  'progestin-only': 171,
#  're-evaluation': 171,
#  'step-wise': 280,
#  'age-groups,': 102,
#  '2-': 90,
#  '5-mg': 605,
#  'enzyme-inducing': 237,
#  '4-week': 267,
#  'drug-induced': 328,
#  'blood-glucose-lowering': 120,
#  'anti-diabetic': 66,
#  'around-the-clock': 281,
#  '(single-': 98,
#  'multiple-dose)': 96,
#  'multiple-dose': 429,
#  'single-dose': 1934,
#  '10-15': 431,
#  'atropine-like': 140,
#  'low-dose': 344,
#  'opioid-naïve': 130,
#  'non-tolerant': 180,
#  '24-hr': 98,
#  'physically-dependent': 338,
#  '24-72': 339,
#  'community-based': 589,
#  'immediate-release': 1856,
#  'opioid-related': 1597,
#  'drug-seeking': 635,
#  'opioid-dependent': 589,
#  'follow-up': 1232,
#  'evidence-based': 719,
#  'co-morbid': 483,
#  'patient-specific': 752,
#  'opioid-dependent,': 620,
#  'dose-lowering': 532,
#  'β-hemolytic': 270,
#  'near-normal': 96,
#  'mg-tablet.': 34,
#  'flare-up': 752,
#  '1-10': 527,
#  'well-ventilated': 389,
#  'fixed-dose': 484,
#  'dose-limiting': 170,
#  'hiv-1-infected': 189,
#  'six-': 4,
#  'eight-hour': 85,
#  'pituitary-adrenal': 333,
#  're-establishment': 289,
#  'off-steroid': 649,
#  're-instituted.': 240,
#  'benefit-risk': 342,
#  '21-day': 479,
#  'free-flowing': 21,
#  'peri-venous': 4,
#  '241(23):2,530-2,533.': 7,
#  '8-aminoquinoline': 48,
#  '80-mg': 608,
#  'statin-based': 28,
#  'drug-drug': 265,
#  'ldl-c': 1879,
#  '40-mg': 157,
#  'ldl-c-lowering': 227,
#  'lipid-lowering': 923,
#  'one-day': 379,
#  'seven-day': 492,
#  're-treatment.': 119,
#  're-titration': 61,
#  'dose-response': 522,
#  'extented-release': 9,
#  '30-45': 71,
#  'intra-arterial': 467,
#  're-evaluate': 1077,
#  'steady-state': 1526,
#  'short-term,': 133,
#  'selection-oral': 21,
#  'flexible-dose': 317,
#  '(non-digitalized': 23,
#  'alpha-agonists,': 34,
#  'nucleoside-inhibitor-treatment-naïve': 51,
#  'lamivudine-experienced': 33,
#  'lamivudine-refractory': 39,
#  'treatment-naïve': 127,
#  'maxalt-mlt': 3,
#  'co-administered': 1401,
#  '10-mg': 458,
#  '30-day': 168,
#  'propranolol-treated': 50,
#  'tramadol-containing': 82,
#  '3-week': 97,
#  '7-day': 184,
#  '1-hour': 162,
#  '1-week': 98,
#  'pre-medication,': 24,
#  'coumarin-derivative': 24,
#  '-1st': 63,
#  '-2nd': 42,
#  '-3rd': 42,
#  '-4th': 21,
#  'hand-and-foot': 48,
#  'two-week': 202,
#  'thiazide-type': 130,
#  'one-': 118,
#  'beta-blockers': 273,
#  'post-myocardial': 463,
#  '(one-': 9,
#  'back-titrated': 22,
#  'flare-ups': 205,
#  'first-degree': 66,
#  '7-': 105,
#  '24-35': 521,
#  '36-47': 465,
#  '4-5': 602,
#  '48-59': 434,
#  '6-8': 1178,
#  '60-71': 435,
#  '9-10': 445,
#  '72-95': 437,
#  'acid-base': 308,
#  'intra-abdominal),': 23,
#  'non-narcotic': 49,
#  'asa-ps': 424,
#  'well-studied': 20,
#  'half-hour': 65,
#  'ready-to-use': 140,
#  'y-type': 69,
#  'in-line': 260,
#  'self-administration': 55,
#  'single-patient': 45,
#  'build-up': 62,
#  'infusion-related': 337,
#  'age-specific': 48,
#  '-m': 79,
#  'beta-lactam': 71,
#  'antibiotic-associated': 42,
#  'renally-impaired': 507,
#  'nsaid-associated': 206,
#  'zollinger-ellison': 843,
#  'catheter-tipped': 139,
#  'p-gp': 352,
#  'ldl-cholesterol': 69,
#  'hmg-coa': 391,
#  '20-mg': 72,
#  '6-month': 306,
#  '3-month': 171,
#  '8-week': 322,
#  'well-fitting,': 412,
#  '(pea-size)': 1,
#  '4-6': 779,
#  'soybean-based': 220,
#  'non-elderly': 541,
#  'free-t4': 1374,
#  '(l-thyroxine)': 48,
#  '(0-3': 220,
#  '0-3': 149,
#  '3-6': 203,
#  '6-12': 486,
#  'one-fourth': 733,
#  'pre-existing': 549,
#  'trimester-specific': 874,
#  'pre-pregnancy': 326,
#  'well-differentiated': 361,
#  'high-risk': 471,
#  'free-t4.': 268,
#  'pituitary-thyroid': 293,
#  'short-term': 1518,
#  'non-erosive': 107,
#  '2-4': 666,
#  '50-100': 75,
#  '--': 757,
#  '5-7': 170,
#  '6-16,': 16,
#  '80-320': 20,
#  '6-16': 43,
#  '1-4mg': 1,
#  '40-160': 32,
#  '20-160': 24,
#  'milligram-per-milligram': 146,
#  'child-resistant': 402,
#  'screw-cap': 128,
#  '*ora-sweet': 61,
#  'volume-depleted.': 63,
#  'beta-blockers,': 219,
#  '3-5': 182,
#  'hiv-1': 1117,
#  'low-strength': 24,
#  'pre-exposure': 34,
#  'hiv-uninfected': 54,
#  'two-drug': 34,
#  're-assess': 48,
#  're-': 4,
#  'one-month': 138,
#  '12-17': 50,
#  '6-11': 235,
#  '18-23': 42,
#  '12-23': 42,
#  '1-2': 805,
#  '8-': 264,
#  '12-hour': 507,
#  'sugar-free': 70,
#  'age-appropriate': 88,
#  'post-exposure': 299,
#  'pre-exposure)': 136,
#  '(>60-90': 46,
#  '(>30-60': 46,
#  '(>10-30': 46,
#  'fda-approved,': 58,
#  '10-day': 73,
#  'ora-sweet®': 105,
#  '(sugar-free)': 57,
#  'opioid-free': 55,
#  'non-opioid': 305,
#  'compliance-enhancing': 38,
#  'non-agonist': 17,
#  'portal-systemic': 18,
#  'single-daily': 150,
#  'anti-manic': 75,
#  '(10-15': 50,
#  'co-administration': 1460,
#  'chemotherapy-naïve:': 14,
#  'node-positive': 49,
#  'g-csf': 208,
#  'non-small': 200,
#  'platinum-based': 127,
#  'treatment-related': 112,
#  'chemotherapy-naïve': 38,
#  'castration-resistant': 131,
#  '30-minute': 220,
#  'non-hematological': 100,
#  'non-hematologic': 512,
#  'nci-ctcae': 30,
#  'plantar-palmar': 36,
#  '(di-2-ethylhexyl': 37,
#  'polyethylene-lined': 51,
#  'semi-logarithmic': 2,
#  '1-8': 32,
#  'broad-spectrum': 318,
#  '10am-2pm': 97,
#  'non-sterile.': 3,
#  'non-sterile': 11,
#  'post-implant': 11,
#  'dose-titration': 19,
#  'anti-spasmotics': 3,
#  'beta-blocking': 4,
#  '1-16': 48,
#  '36-48': 12,
#  'glucocorticoid-induced': 85,
#  're-treatment': 166,
#  'six-month': 33,
#  'post-treatment': 115,
#  '(6-8': 18,
#  'home-bound,': 31,
#  '25-hydroxyvitamin': 70,
#  'once-weekly': 53,
#  'gram-positive': 71,
#  '2-minute': 197,
#  'un-chewed': 81,
#  'broad-': 5,
#  'next-day': 73,
#  'cns-depressant': 77,
#  'epididymo-orchitis': 465,
#  '(post-exposure)': 970,
#  'well-tolerated.': 20,
#  'well-tolerated,': 54,
#  're-initiation': 347,
#  're-initiate': 57,
#  'co-medications': 25,
#  'co-medication': 77,
#  'inter-patient': 583,
#  'dose-dependent': 1133,
#  'dose-independent': 411,
#  'blood-pressure': 73,
#  'potassium-sparing': 265,
#  '300-mg-per-day': 21,
#  'non-pharmacological': 376,
#  'intra-thoracic': 17,
#  'intra-abdominal': 518,
#  '6-': 129,
#  '8-hour': 332,
#  'post-dose': 138,
#  'post-dose,': 122,
#  'semi-solid': 77,
#  '5-ml': 67,
#  're-suspend': 8,
#  '9-10.': 2,
#  'nityr-applesauce': 2,
#  '20-30': 301,
#  'mg-per-mg': 158,
#  'added-on': 18,
#  '20-25': 54,
#  '(68-77': 53,
#  'partial-onset': 953,
#  'on-going': 199,
#  '4-hour': 461,
#  '1-800-525-8747': 1,
#  '1-800-fda-1088': 58,
#  'non-black': 9,
#  'twice-daily': 872,
#  'left-ventricular': 10,
#  '(child-': 11,
#  'y-site': 421,
#  'high-fat': 178,
#  'corticosteroid-responsive': 25,
#  'schizophrenia-adults': 222,
#  'schizophrenia-adolescents': 203,
#  'mania-': 338,
#  'depression-adults': 151,
#  'mg-50': 49,
#  'schizophrenia-': 140,
#  '400-800': 229,
#  'schizophrenia-maintenance': 109,
#  '400-600': 82,
#  'depression-': 56,
#  'therapy-': 87,
#  'co-medicated': 153,
#  '6-fold': 112,
#  '5-fold': 128,
#  '7-14': 252,
#  'one-week,': 208,
#  're-initiated.': 135,
#  '6-mg': 26,
#  'l-a': 2,
#  '---': 174,
#  '(6-16': 12,
#  '1.3-2.7': 11,
#  '(2-8°c': 3,
#  '35-46°f)': 2,
#  'pre-treatment': 176,
#  '15-20': 94,
#  '3-times-daily': 40,
#  'beta-blocker': 364,
#  'alpha-adrenergic': 230,
#  'tablets-associated': 32,
#  'tablets-': 2,
#  'lennox-gastaut': 367,
#  '600-mg': 18,
#  'one-third': 294,
#  're-prime': 18,
#  '24-hours': 47,
#  'sustained-release': 327,
#  'mg-for-mg': 32,
#  'three-': 35,
#  'hormone-releasing': 33,
#  'counter-clockwise': 55,
#  '(luer-lok)': 26,
#  '(luer-lok).': 27,
#  '(1-2': 86,
#  'single-finger': 23,
#  'non-toxic': 24,
#  'non-pyrogenic.': 57,
#  'six-day': 39,
#  'carbidopa-levodopa,': 90,
#  '1-844-740-7500.': 7,
#  'west-ward)': 6,
#  '4-fold': 32,
#  'fold-volume': 2,
#  'digoxin-like': 37,
#  '10-25%': 15,
#  '4-minute': 17,
#  '(step-wise': 26,
#  'heart-rate': 17,
#  'rate-lowering': 26,
#  '(250-300': 9,
#  'hand-held': 56,
#  'calcium-containing': 480,
#  'y-site.': 89,
#  'ano-genital': 42,
#  '3-hour': 90,
#  'needle-stick': 94,
#  'opioid-': 31,
#  'co-infusion': 18,
#  'co-infusions': 17,
#  '6-,': 5,
#  '8-,': 5,
#  'imipenem-cilastatin': 5,
#  'fine-tooth': 51,
#  'throw-away': 57,
#  'x-ray,': 34,
#  '9-11': 150,
#  '(60-95': 149,
#  '(48-59': 155,
#  '2-5': 290,
#  'pari-lc-plus™': 17,
#  '(pre-dosing)': 76,
#  'ora-plus®*': 55,
#  'ora-sweet®*': 42,
#  '*ora-plus®': 38,
#  'infusion-associated': 28,
#  're-escalate': 7,
#  'protein-binding': 14,
#  'dehp-free': 7,
#  'half-tablet,': 174,
#  'half-tablet': 174,
#  'half-tablets': 153,
#  'add-on': 235,
#  '(0.85)(140-age)(weight)': 4,
#  '(140-age)(weight)': 4,
#  'post-hemodialysis': 650,
#  '900-3600': 9,
#  '30-59': 18,
#  '400-1400': 9,
#  '15-29': 26,
#  '200-700': 9,
#  '100-300': 9,
#  'exercise-induced': 208,
#  'air-dry': 45,
#  'pre-mixed': 19,
#  'two-port': 11,
#  're-evaluation.': 177,
#  'varicella-zoster': 186,
#  '6-hour': 349,
#  '800-mg': 74,
#  '200-mg': 117,
#  '500-mg': 158,
#  '875-mg': 150,
#  '250-mg': 185,
#  'tamper-evident': 72,
#  'cholesterol-lowering': 275,
#  'lipid-altering': 102,
#  'bile-acid-binding': 104,
#  '1.26-1.37': 9,
#  '1.38-1.51': 9,
#  '1.52-1.65': 9,
#  '1.66-1.77': 9,
#  '1.78-1.91': 9,
#  '1.92-2.05': 9,
#  '2.06-2.17': 9,
#  '0-1': 64,
#  '0-1;': 24,
#  're-evaluated.': 59,
#  'pre-prepared': 44,
#  'salt-depleted': 45,
#  'deeply-connecting': 6,
#  'only-fatal': 1,
#  'l-asparaginase,': 1,
#  'l-asparaginase': 4,
#  '5-ht': 329,
#  'in-office': 157,
#  '0.15-mg': 34,
#  'first-day': 66,
#  '15-minute': 209,
#  'opioid-containing': 86,
#  'fixed-ratio': 108,
#  'hepatically-impaired,': 5,
#  '5-days': 25,
#  'breast-feeding;': 25,
#  'breast-feeding,': 31,
#  'hla-b*5701': 72,
#  'copper-free': 14,
#  'ceruloplasmin-copper.': 11,
#  'protein-free': 18,
#  'self-limited': 117,
#  'non-steroidal': 156,
#  'anti-anxiety': 53,
#  'nucleoside\xadinhibitor-treatment-naïve': 1,
#  'treatment-na': 1,
#  'second-': 75,
#  'third-degree': 80,
#  'cns-acting': 106,
#  '20°-25°c(68°-77°f)': 1,
#  '1-800-222-1087': 2,
#  'p-glycoprotein': 77,
#  '(p-gp)': 73,
#  'tsc-associated': 53,
#  '5-15': 75,
#  'receptor-positive,': 12,
#  'her2-negative': 11,
#  '(tsc)-associated': 20,
#  'p-gp,': 6,
#  'p-glycoprotein.': 5,
#  'non-infectious': 31,
#  '70-kg': 152,
#  'low-birth': 19,
#  '5-phosphate': 6,
#  '-pantothenyl': 6,
#  '-α-tocopheryl': 5,
#  'thirty-three': 3,
#  'pea-sized': 398,
#  'medi-hands': 2,
#  'tonic-clonic': 828,
#  '7-8': 86,
#  'vancomycin-resistant': 63,
#  'pre-term': 73,
#  'full-term': 215,
#  'sub-optimal': 33,
#  '5-11': 14,
#  'mild-to-moderate': 480,
#  'ora-plus™': 92,
#  'sunday-start': 53,
#  'day-1': 54,
#  'self-adhesive': 20,
#  'on-1': 3,
#  '21-tablet': 23,
#  'on-7': 5,
#  '40-100': 138,
#  'binge-eating': 150,
#  're-examine': 320,
#  '(10-17': 69,
#  '(fixed-dose': 125,
#  'non-smoking': 129,
#  're-inserting': 1,
#  '40-80': 59,
#  'mg-80': 40,
#  're-epithelialisation': 13,
#  '2-5)': 9,
#  '6-11)': 9,
#  '24-47': 16,
#  '48-95': 43,
#  '24-': 44,
#  're-initiated)': 12,
#  'potassium-depleting': 11,
#  '(140-age)': 103,
#  'in-hospital': 35,
#  'half-lives.': 13,
#  'preservative-free': 386,
#  'anticoagulant-induced': 48,
#  '15-g': 20,
#  'neuro-psychiatric': 72,
#  'intra-articular': 583,
#  '20-': 17,
#  '24-gauge': 12,
#  '1.0-2.0': 4,
#  '0.5-1.0': 36,
#  '0.25-0.5': 4,
#  '25-gauge,': 24,
#  '½-inch': 14,
#  '¾-inch': 2,
#  'emete-con': 36,
#  'levo-dromoran': 37,
#  'histamine-mediated': 180,
#  'cross-study': 8,
#  '8-week,': 109,
#  'acute-treatment': 114,
#  'open-label': 80,
#  'double-blind': 49,
#  '[140-age': 123,
#  '-------------------------------------------------------------------------': 2,
#  '----------------------------': 13,
#  'opioid-tolerant.': 30,
#  'opioid-tolerant': 233,
#  '60-134': 48,
#  '135-224': 48,
#  '225-314': 48,
#  '315-404': 48,
#  '10-22': 24,
#  '23-37': 24,
#  '38-52': 24,
#  '53-67': 24,
#  '30-67': 24,
#  '67.5-112': 24,
#  '112.5-157': 24,
#  '157.5-202': 24,
#  '150-447': 24,
#  '8-17': 32,
#  '17.1-28': 24,
#  '28.1-39': 24,
#  '39.1-51': 24,
#  '1.5-3.4': 24,
#  '3.5-5.6': 24,
#  '5.7-7.9': 24,
#  '8-10': 157,
#  '75-165': 24,
#  '166-278': 24,
#  '279-390': 24,
#  '391-503': 24,
#  '20-44': 24,
#  '45-74': 24,
#  '75-104': 24,
#  '105-134': 24,
#  '405-494': 24,
#  '495-584': 24,
#  '585-674': 24,
#  '675-764': 24,
#  '765-854': 24,
#  '855-944': 24,
#  '945-1034': 24,
#  '1035-1124': 24,
#  '72-hour': 101,
#  'non-irritated,': 25,
#  'non-irradiated': 25,
#  'pre-measured': 23,
#  'intra-articular,': 101,
#  '89(3):495-501.': 92,
#  'bile-acid': 36,
#  '(50-100': 36,
#  'extended-release,': 82,
#  'up-titration.': 543,
#  'extended-release.': 183,
#  'ceteareth-20,': 2,
#  'peg-100': 5,
#  'x-ray': 104,
#  '1-800-828-9393': 4,
#  'iop-lowering': 2,
#  'sulfonylurea-class': 144,
#  'non-insulin-': 14,
#  '(3-4': 27,
#  'blister-packaged': 6,
#  'pre-filled': 119,
#  'self-injection': 53,
#  'non-leukemia': 28,
#  'c-kit': 93,
#  'fip1l1-pdgfrα,': 25,
#  'fip1l1-pdgfrα': 53,
#  'platelet-derived': 11,
#  'desensitization-': 2,
#  '-ask': 1,
#  'polyglyceryl-10': 6,
#  'peg-12': 6,
#  'steareth-20,': 6,
#  'c13-14': 7,
#  'laureth-7,': 7,
#  '8-12': 225,
#  '0.5-1': 20,
#  '7-10': 60,
#  '-r': 33,
#  '-r,': 9,
#  '(post-exposure):': 175,
#  'mania-children': 51,
#  'therapy-adults': 23,
#  'tobramycin-spl-figure': 2,
#  'calcium-based': 26,
#  '-initially,': 14,
#  'longer-acting': 25,
#  'within-day': 13,
#  'beta-adrenergic': 100,
#  'up-titration': 143,
#  'β-blocker': 126,
#  '24-mg': 31,
#  '8-mg': 146,
#  '4-mg': 256,
#  'thallium-201': 37,
#  'a.m.-2p.m.': 32,
#  'chemotherapy-induced': 79,
#  '20-25°c': 131,
#  '(68-77°f)': 117,
#  'non-dialysis': 130,
#  'full-dose': 151,
#  'weight-adjusted': 61,
#  'anti-factor': 99,
#  'open-heart': 98,
#  '26-gauge)': 41,
#  'gabapentin-equation': 37,
#  'skin-structure': 73,
#  'mania-adults': 25,
#  'cockcroft-gault-equation.jpg': 1,
#  '-------------------------------------------------------------': 5,
#  '----------------------------------------------(x': 16,
#  '--------------------------': 19,
#  '----': 79,
#  'ceftriaxone-calcium': 107,
#  'normosol-m': 46,
#  'ionosol-b': 42,
#  '(-20°c)': 42,
#  'one-week': 167,
#  'super-': 13,
#  'non-vented': 34,
#  'di-2-ethylhexyl': 14,
#  'angle-closure': 76,
#  'open-angle': 49,
#  'angle-closure,': 22,
#  'extended-': 80,
#  'acid-mediated': 771,
#  '200-400': 13,
#  'alpha-blockers': 192,
#  'alpha-blocker': 472,
#  'cockcroft-gault': 430,
#  'non-squamous': 133,
#  'first-line': 69,
#  '0-2,': 21,
#  '100-mg': 189,
#  '(preservative-free)': 84,
#  'green-yellow.': 20,
#  '[2-8°c': 28,
#  '(36-46°f)]': 24,
#  'starch-based': 25,
#  '------------------------------------------------------': 12,
#  'dose-reductions': 22,
#  'ckd-epi,': 64,
#  'non-transfusion-dependent': 83,
#  'fda-cleared': 37,
#  '1-month': 66,
#  'aluminum-containing': 34,
#  'transfusion-dependent': 23,
#  'nephrotoxic-therapies': 7,
#  '-17': 34,
#  'udp-glucuronosyltransferases': 33,
#  'non-emergent': 48,
#  'non-emergency': 21,
#  'large-gauge': 12,
#  'dextrose-containing': 56,
#  "'fluid-air": 2,
#  'air-fluid': 1,
#  'take1-2': 5,
#  'tablet-free': 3,
#  'back-up': 139,
#  '28-day': 559,
#  'second-trimester': 20,
#  'tablet-taking.': 3,
#  'first-trimester': 18,
#  'three-drug': 39,
#  'short-course': 40,
#  '4-ounce': 19,
#  'above-mentioned': 10,
#  'pressure-lowering': 27,
#  '68°-77°f': 2,
#  '20°-': 5,
#  'high-intensity': 58,
#  '2-inch': 72,
#  'circulatory-': 1,
#  'allergic-': 1,
#  'stevens-johnson': 16,
#  'other-': 1,
#  '(single-dose': 15,
#  'mu-opioid': 29,
#  'long-': 75,
#  'methadone-maintained': 21,
#  'take-home': 111,
#  'once-monthly': 76,
#  'recovery-oriented': 56,
#  'medication-assisted': 57,
#  '(hiv-1': 18,
#  'lead-in': 179,
#  'every-2-month': 10,
#  'sub-therapeutic': 24,
#  'caffeine-like': 20,
#  'steady-state.': 48,
#  '-adrenergic': 7,
#  '2-7': 5,
#  '9-14': 2,
#  '16-21': 2,
#  '23-28': 2,
#  '1.5-3': 25,
#  '(sanofi-aventis': 11,
#  'syrups-simple': 8,
#  'non-induced': 30,
#  'non-enzyme-inducing': 6,
#  're-usable.': 60,
#  'once-daily.': 98,
#  'mg-3200': 57,
#  'well-controlledclinical': 36,
#  'delayed-': 28,
#  'androgen-deficient': 4,
#  'one-sixth': 15,
#  'glucose-containing': 78,
#  '1-year': 93,
#  '5-year': 103,
#  '10-year': 93,
#  '15-year': 93,
#  '------------------------------------------------': 26,
#  '--------------------------------': 16,
#  'two-minute': 33,
#  'thyroid-stimulating': 21,
#  'clip-lid': 3,
#  'fresh-seal': 3,
#  '(34-47': 25,
#  'metformin-associated': 16,
#  '-limit': 53,
#  '-1': 104,
#  '-2': 158,
#  '-3': 47,
#  '-4': 8,
#  'in-hospital.': 35,
#  'age-adjusted': 35,
#  'half-lives': 155,
#  '6-ounce': 35,
#  'water-insoluble': 31,
#  '(20°-25°c': 3,
#  '68°-77°f)': 2,
#  'two-years': 210,
#  'acid-stable': 40,
#  'beta-hemolytic': 146,
#  '15-21': 8,
#  'injection-related': 69,
#  'risk-benefit': 207,
#  'dose-intense': 25,
#  '(life-threatening': 28,
#  '300-mg': 148,
#  '(immediate-release),': 73,
#  '(child-pugh=5': 78,
#  '(child-pugh=7': 78,
#  '(child-pugh=10': 78,
#  '-release': 8,
#  'around-the': 5,
#  '-clock': 3,
#  'renin-angiotensin': 31,
#  'cockcroft-gault)': 67,
#  '-or-': 56,
#  'impairment-do': 49,
#  '3-cm': 14,
#  'adams-stokes': 11,
#  'post-operative': 99,
#  '8-to': 10,
#  'ery-ped': 1,
#  'twice-a-day': 474,
#  '30-50': 44,
#  '15-25': 15,
#  '-xr': 54,
#  '-xr,': 6,
#  'age-initial': 72,
#  '10-20': 407,
#  '(12-15': 20,
#  'tegretol-xr': 20,
#  '59°-86°f': 4,
#  '(15°-30°c)': 3,
#  'break-up': 1,
#  'non-preserved': 2,
#  '185-370': 1,
#  '(5-10': 42,
#  'non-diabetic': 1,
#  '50-75': 19,
#  'non-ischemic': 1,
#  '30-100': 4,
#  '--------------------------------------------------------': 7,
#  '---------------------------------------': 8,
#  '-------------------': 5,
#  '15°-25°c': 2,
#  '(59°-77°f)': 2,
#  'drug-resistant': 29,
#  'sugar-coated': 2,
#  '5-': 86,
#  '2-8°c': 75,
#  '(36-46°f)': 73,
#  'age-related': 15,
#  'brownish-yellow': 7,
#  '5-micron': 22,
#  '18-gauge': 14,
#  '30-gauge': 23,
#  'flip-off': 78,
#  'alpha-naïve': 6,
#  '(hcv)-rna': 3,
#  'hcv-rna': 30,
#  're-treated': 3,
#  '66-80': 2,
#  '81-105': 1,
#  '3-17': 2,
#  '47-59': 1,
#  '60-73': 1,
#  'two-step': 17,
#  'four-week': 14,
#  'interferon-alfa-naïve': 3,
#  '(3-17': 1,
#  'non-affected': 11,
#  'non-medicated': 29,
#  'super-high': 102,
#  '0-10': 449,
#  '10-25': 182,
#  '12-72': 23,
#  'bulk-forming': 17,
#  'once-a-week': 67,
#  'magnesium-based': 15,
#  'once-a-week,': 24,
#  '(75-mg': 10,
#  '325-mg)': 10,
#  '10-': 62,
#  'half-life,': 95,
#  'two-hour': 138,
#  'volume-contracted.': 40,
#  '1-minute': 103,
#  '(auto-injector)': 14,
#  'auto-injector': 128,
#  '-apply': 83,
#  '-children': 81,
#  'first-level': 5,
#  '(modified-release,': 18,
#  'timed-release)': 18,
#  'adult-equivalent': 30,
#  'estrogen-alone': 8,
#  'dilantin-125': 11,
#  'self-help': 37,
#  'non-psychotic': 109,
#  'on-treatment': 40,
#  'twice-a-day.': 204,
#  'twice-a-day);': 41,
#  'twice-a-day,': 41,
#  'twice-a-day)': 41,
#  'ml-2.5': 3,
#  'mg-100': 3,
#  'ml-3.4': 3,
#  'mg-136': 3,
#  'ml-5.1': 3,
#  'mg-204': 3,
#  '4-16': 38,
#  'co-formulated': 13,
#  '0.2-micron': 10,
#  'co-administering': 11,
#  'skin-to-skin': 181,
#  'fortesta-treated': 1,
#  ...}

# %% [markdown]
# In contrast to words combined with '/', these combined with '-' tend to represent a single concept. Splitting them into separate tokens would lose important information (e.g. 'non-psychotic').

# %% [markdown]
# # Final Tokenization

# %% [markdown]
# Based on the above analysis, we will split on whitespace and '/', and remove punctuation.

# %%
punct_set = set(punctuation)
punct_set.remove('/') # don't remove '/' because we need it for tokenization

# %%
def remove_punctuation(text):
    return "".join([char for char in text if char not in punct_set])

# %%
pipeline = [str.lower, remove_punctuation, tokenize]

# %%
prepare('This is an example/test sentence!', pipeline=pipeline)
# Out:
# ['this', 'is', 'an', 'example', 'test', 'sentence']

# %%
df['tokens_final'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df.head()
# Out:
#        target                                               text  \
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...
#
#                                               tokens  \
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...
#
#                                         tokens_slash  \
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...
#
#                                         tokens_final
# 0  [dosage, adults, take, 4, or, 6, pellets, by, ...
# 1  [directions, adults, dissolve, 3, to, 5, under...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face, apply, to, hand, massa...

# %%
# create list of all tokens
all_tokens = []
df['tokens_final'].apply(lambda x: all_tokens.extend(x))
print(len(all_tokens))
# Out:
# 24308694

# %%
token_counts = Counter(all_tokens)

# %%
types = token_counts.keys()

# %%
print("Splitting on whitespace and '/' and removing punctuation yields {0} tokens and {1} types.".format(token_counts.total(), len(types)))
# Out:
# Splitting on whitespace and '/' and removing punctuation yields 24308694 tokens and 34091 types.

# %%
token_counts.most_common(50)
# Out:
# [('the', 848968),
#  ('of', 768443),
#  ('to', 635668),
#  ('and', 587914),
#  ('mg', 524520),
#  ('in', 430771),
#  ('for', 371437),
#  ('a', 368313),
#  ('dose', 355760),
#  ('be', 332674),
#  ('or', 330999),
#  ('with', 315480),
#  ('is', 275330),
#  ('patients', 275135),
#  ('dosage', 206939),
#  ('daily', 205849),
#  ('day', 203925),
#  ('should', 201968),
#  ('not', 182158),
#  ('2', 171345),
#  ('tablets', 162120),
#  ('may', 143918),
#  ('as', 142491),
#  ('use', 132066),
#  ('recommended', 127493),
#  ('at', 120074),
#  ('1', 116033),
#  ('hours', 114260),
#  ('see', 113201),
#  ('ml', 109814),
#  ('treatment', 104135),
#  ('kg', 100617),
#  ('by', 99299),
#  ('years', 98130),
#  ('on', 96339),
#  ('administration', 95238),
#  ('doses', 95039),
#  ('every', 92562),
#  ('than', 92010),
#  ('if', 90153),
#  ('once', 89047),
#  ('10', 88918),
#  ('12', 87395),
#  ('children', 84198),
#  ('5', 81370),
#  ('4', 78639),
#  ('therapy', 77163),
#  ('after', 76492),
#  ('are', 75090),
#  ('clinical', 74409)]

# %% [markdown]
# ## Stopwords EDA

# %%
#install the ntlk package
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Luke-
# [nltk_data]     Workstation\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopWords = stopwords.words('english') # will start of with english stopwords
print(len(stopWords)) # check the number of stopwords
# Out:
# 179

# %%
print(stopWords) # print out the stopwords
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
df.head(10) # check the df to get an idea of the words
# Out:
#        target                                               text  \
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...
# 5        ORAL  Dissolve pellets under the tongue 3-4 times da...
# 6        ORAL  2 DOSAGE AND ADMINISTRATION The recommended do...
# 7        ORAL  2 DOSAGE AND ADMINISTRATION Recommended starti...
# 8        ORAL  DOSAGE AND ADMINISTRATION Methocarbamol tablet...
# 9     TOPICAL  Directions • for itching of skin irritation, i...
#
#                                               tokens  \
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...
# 5  [dissolve, pellets, under, the, tongue, 3-4, t...
# 6  [2, dosage, and, administration, the, recommen...
# 7  [2, dosage, and, administration, recommended, ...
# 8  [dosage, and, administration, methocarbamol, t...
# 9  [directions, •, for, itching, of, skin, irrita...
#
#                                         tokens_slash  \
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...
# 5  [dissolve, pellets, under, the, tongue, 3-4, t...
# 6  [2, dosage, and, administration, the, recommen...
# 7  [2, dosage, and, administration, recommended, ...
# 8  [dosage, and, administration, methocarbamol, t...
# 9  [directions, •, for, itching, of, skin, irrita...
#
#                                         tokens_final
# 0  [dosage, adults, take, 4, or, 6, pellets, by, ...
# 1  [directions, adults, dissolve, 3, to, 5, under...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face, apply, to, hand, massa...
# 5  [dissolve, pellets, under, the, tongue, 34, ti...
# 6  [2, dosage, and, administration, the, recommen...
# 7  [2, dosage, and, administration, recommended, ...
# 8  [dosage, and, administration, methocarbamol, t...
# 9  [directions, •, for, itching, of, skin, irrita...

# %%
#function for removing the stopwords from the token column
def remove_stopwords(text):
    return " ".join(word for word in str(text).split() if word not in stopWords)

# %%
# function  for cleaning the stopwords
text_st = ' when is a good time to go running only for about five hours and again look above'
remove_stopwords(text_st)
# Out:
# 'good time go running five hours look'

# %%
#check the output from the text column
df['stop_removed'] = df['text'].apply(lambda text: remove_stopwords(text))
df['stop_removed'].head(10)
# Out:
# 0    DOSAGE Adults- Take 4 6 Pellets mouth, three t...
# 1    DIRECTIONS Adults: Dissolve 3 5 tongue three t...
# 2    DOSAGE AND ADMINISTRATION The recommended dosa...
# 3    2 DOSAGE AND ADMINISTRATION Use lowest effecti...
# 4    Directions wet face, apply hand, massage face ...
# 5    Dissolve pellets tongue 3-4 times daily. Ages ...
# 6    2 DOSAGE AND ADMINISTRATION The recommended do...
# 7    2 DOSAGE AND ADMINISTRATION Recommended starti...
# 8    DOSAGE AND ADMINISTRATION Methocarbamol tablet...
# 9    Directions • itching skin irritation, inflamma...
# Name: stop_removed, dtype: object

# %%
#check the function on the tokens
df['stop_removed_tokens'] = df['tokens_final'].apply(lambda text: remove_stopwords(text))
# df['stop_removed_tokens']= df['stop_removed_tokens'].astype(str)
df['stop_removed_tokens'].head(10)
# Out:
# 0    ['dosage', 'adults', 'take', '4', 'or', '6', '...
# 1    ['directions', 'adults', 'dissolve', '3', 'to'...
# 2    ['dosage', 'and', 'administration', 'the', 're...
# 3    ['2', 'dosage', 'and', 'administration', 'use'...
# 4    ['directions', 'wet', 'face', 'apply', 'to', '...
# 5    ['dissolve', 'pellets', 'under', 'the', 'tongu...
# 6    ['2', 'dosage', 'and', 'administration', 'the'...
# 7    ['2', 'dosage', 'and', 'administration', 'reco...
# 8    ['dosage', 'and', 'administration', 'methocarb...
# 9    ['directions', '•', 'for', 'itching', 'of', 's...
# Name: stop_removed_tokens, dtype: object

# %% [markdown]
# the function didnt remove the stopwords from the tokens , the next step create a function for the tokenized words

# %%
#function for removing the stopwords from the token column
def remove_stop_tokens(tokens):
    words = [ t for t in tokens if not t in stopWords]
    return " ".join(words)

# %%
#check the remove token function 
df['stop_removed_tokens'] = df['tokens_final'].apply(lambda text: remove_stop_tokens(text))
# df['stop_removed_tokens']= df['stop_removed_tokens'].astype(str)
df['stop_removed_tokens'].head(10)
# Out:
# 0    dosage adults take 4 6 pellets mouth three tim...
# 1    directions adults dissolve 3 5 tongue three ti...
# 2    dosage administration recommended dosage regim...
# 3    2 dosage administration use lowest effective d...
# 4    directions wet face apply hand massage face ge...
# 5    dissolve pellets tongue 34 times daily ages 12...
# 6    2 dosage administration recommended dosage mek...
# 7    2 dosage administration recommended starting d...
# 8    dosage administration methocarbamol tablets us...
# 9    directions • itching skin irritation inflammat...
# Name: stop_removed_tokens, dtype: object

# %%
print(df['stop_removed_tokens'].head(20))
# Out:
# 0     dosage adults take 4 6 pellets mouth three tim...
# 1     directions adults dissolve 3 5 tongue three ti...
# 2     dosage administration recommended dosage regim...
# 3     2 dosage administration use lowest effective d...
# 4     directions wet face apply hand massage face ge...
# 5     dissolve pellets tongue 34 times daily ages 12...
# 6     2 dosage administration recommended dosage mek...
# 7     2 dosage administration recommended starting d...
# 8     dosage administration methocarbamol tablets us...
# 9     directions • itching skin irritation inflammat...
# 10    dosage administration dosage thyroid hormones ...
# 11    directions use care premature infants infants ...
# 12    directions adults apply 2 sprays onto tongue a...
# 13    directions take directed adults children 12 ye...
# 14    directions take 6 doses 24hour period measure ...
# 15    directions instill 1 2 drops affected eyes needed
# 16    dosage administration section directions ages ...
# 17    2 dosage administration apply thin film betame...
# 18                      directions apply locally needed
# 19    2 dosage administration recommended initial do...
# Name: stop_removed_tokens, dtype: object

# %% [markdown]
# words such as directions,dosage appear frequently given that it a dataset involving drugs is to be expected, the next step is to plot the frequent words and add frequent ones to the stopwords

# %%
# plot the distribution of the words and compare the frequency after removing stop words
flatten_tokens = [y for x in df['tokens_final'] for y in x]  # flatten the list of token lists to a single list
print("flatten_tokens[:10]:", flatten_tokens[:10])

freq_tokens = nltk.FreqDist(flatten_tokens)
del freq_tokens['']
freq_sorted = sorted(freq_tokens.items(), key=lambda x: x[1], reverse=True)  # sorted list
# print(freq_sorted) # prints everything
    
freq_tokens.plot(30, cumulative=False)
# Out:
# flatten_tokens[:10]: ['dosage', 'adults', 'take', '4', 'or', '6', 'pellets', 'by', 'mouth', 'three']
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# below the stopwords are removed, additional stopwords were added to the list , this included some of the top reoccuring tokens

# %%
#add new words to the stopwords list
additional_stopwords = ["dosage","directions","dose", "day", "should", "not","recommended","with","patients","administration","doses","daily","mg","kg","1","10","12","5","4","2","adults","take","6","mouth","three","times"]
stopWords.extend(additional_stopwords)
len(stopWords)# check to see if the words have been added
# Out:
# 303

# %%
pipeline = [str.lower,remove_stopwords, remove_punctuation, tokenize]

# %%
df['stop_removed_tokens'] = df['text'].apply(prepare, pipeline=pipeline)
df['stop_removed_tokens'].head(10)
# Out:
# 0    [adults, pellets, mouth, suggested, physician,...
# 1    [adults, dissolve, 3, tongue, directed, lic, p...
# 2    [regimen, treatment, bacterial, conjunctivitis...
# 3    [use, lowest, effective, shortest, duration, c...
# 4    [wet, face, apply, hand, massage, face, gently...
# 5    [dissolve, pellets, tongue, 34, daily, ages, o...
# 6    [mekinist, adult, orally, daily, mekinist, ped...
# 7    [starting, daily, increase, increments, freque...
# 8    [methocarbamol, tablets, usp, 500, –, adults, ...
# 9    [•, itching, skin, irritation, inflammation, r...
# Name: stop_removed_tokens, dtype: object

# %%
#plot after stopword removal
flatten_tokens2=[y for x in df['stop_removed_tokens']for y in x]
print("flatten_tokens2[:10]:", flatten_tokens2[:10])
freq_tokens2 = nltk.FreqDist(flatten_tokens2)
freq_sorted2 = sorted(freq_tokens2.items(), key=lambda x: x[1], reverse=True)  # sorted list
# print(freq_sorted2)
    
freq_tokens2.plot(30, cumulative=False)
# Out:
# flatten_tokens2[:10]: ['adults', 'pellets', 'mouth', 'suggested', 'physician', 'children', 'years', 'older', '1', '2']
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %%
import pandas as pd
from collections import Counter
from string import punctuation
import re
import matplotlib.pyplot as plt 
import seaborn as sns
from src.data.cleaning import prepare

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('../data/processed/drugs.csv', usecols=['target', 'text'])

# %%
df.head()
# Out:
#        target                                               text
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...

# %% [markdown]
# # Split on Whitespace

# %% [markdown]
# The simplest tokenization just splits on whitespace. Let's try this and explore the results.

# %%
pipeline = [str.lower, str.split]

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df.head()
# Out:
#        target                                               text  \
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...
#
#                                               tokens
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...

# %%
# create list of all tokens
all_tokens = []
df['tokens'].apply(lambda x: all_tokens.extend(x))
print(len(all_tokens))
# Out:
# 24417311

# %%
token_counts = Counter(all_tokens)

# %%
types = token_counts.keys()

# %%
print("Splitting on whitespace yields {0} tokens and {1} types.".format(token_counts.total(), len(types)))
# Out:
# Splitting on whitespace yields 24417311 tokens and 64217 types.

# %%
token_counts.most_common(50)
# Out:
# [('the', 848509),
#  ('of', 767519),
#  ('to', 633353),
#  ('and', 575928),
#  ('in', 429169),
#  ('for', 368567),
#  ('a', 364741),
#  ('be', 332954),
#  ('mg', 324956),
#  ('or', 316372),
#  ('with', 314054),
#  ('dose', 312668),
#  ('is', 274114),
#  ('patients', 240936),
#  ('should', 200650),
#  ('dosage', 196129),
#  ('not', 180926),
#  ('daily', 147901),
#  ('2', 147387),
#  ('may', 143437),
#  ('as', 141395),
#  ('tablets', 136138),
#  ('use', 120613),
#  ('at', 119566),
#  ('recommended', 115114),
#  ('(', 107196),
#  ('by', 98774),
#  ('on', 96163),
#  ('than', 91941),
#  ('every', 90590),
#  ('treatment', 89060),
#  ('if', 88278),
#  ('once', 87691),
#  ('1', 86374),
#  ('years', 86196),
#  ('hours', 84761),
#  ('administration', 82238),
#  ('12', 80947),
#  ('10', 78650),
#  ('doses', 76299),
#  ('children', 75698),
#  ('after', 75312),
#  ('are', 74851),
#  ('clinical', 74396),
#  ('day', 72844),
#  ('4', 70366),
#  (')', 70238),
#  ('•', 68972),
#  ('[see', 67113),
#  ('5', 63631)]

# %% [markdown]
# The top 30 typtes contain many stopwords. A few of them contain punctuation.

# %% [markdown]
# Let's look for other types containing punctuation.

# %%
punct_set = set(punctuation)

# %%
def contains_punct(text):
    for char in text:
        if char in punct_set:
            return True
    return False

# %%
types_with_punct = {t: count for t, count in token_counts.items() if contains_punct(t)}

# %%
types_with_punct = sorted(types_with_punct.items(), key=lambda item: item[1], reverse=True)

# %%
types_with_punct[:50]
# Out:
# [('(', 107196),
#  (')', 70238),
#  ('[see', 67113),
#  ('mg/day', 45543),
#  ('.', 44068),
#  ('2.1', 37037),
#  ('daily.', 36106),
#  ('2.2', 32983),
#  ('mg/kg', 32103),
#  (',', 31304),
#  ('extended-release', 28875),
#  ('(see', 27702),
#  (').', 24255),
#  ('2.3', 24155),
#  ('2.5', 24137),
#  ('day.', 21954),
#  (']', 19901),
#  ('].', 19495),
#  ('dose.', 18599),
#  ('2.4', 18500),
#  ('days.', 17312),
#  ('hours.', 15777),
#  (')]', 15025),
#  ('-', 14980),
#  ('mg/kg/day', 13248),
#  ('injection,', 13092),
#  ('tablets,', 12756),
#  ('(e.g.,', 11997),
#  ('mg,', 11711),
#  ('delayed-release', 11687),
#  ('dose,', 11585),
#  ('age:', 11575),
#  ('daily,', 11490),
#  ('patients,', 11078),
#  ('mg.', 10734),
#  ('however,', 10581),
#  ('and/or', 10315),
#  ('doses.', 10265),
#  ('mg/m', 10133),
#  (')].', 10112),
#  ('day,', 9980),
#  ('therapy.', 9594),
#  ('mg/day.', 9437),
#  ('hours,', 9301),
#  ('weeks.', 9253),
#  ('[', 9148),
#  ('response.', 8953),
#  ('recommended.', 8929),
#  ('patients.', 8914),
#  ('patient.', 8805)]

# %% [markdown]
# It seems fairly common for words to be combined with '/'. Let's take a look at these specifically.

# %%
[(t, count) for t, count in dict(types_with_punct).items() if '/' in t][:50]
# Out:
# [('mg/day', 45543),
#  ('mg/kg', 32103),
#  ('mg/kg/day', 13248),
#  ('and/or', 10315),
#  ('mg/m', 10133),
#  ('mg/day.', 9437),
#  ('ml/min', 8163),
#  ('mg/ml', 6077),
#  ('mg/day,', 4372),
#  ('ml/min/1.73', 3477),
#  ('mg/kg/day,', 3105),
#  ('mg/5', 3033),
#  ('mcg/kg/day', 2646),
#  ('mg/125', 2465),
#  ('ml/min)', 2317),
#  ('1/2', 2201),
#  ('ml/min,', 2060),
#  ('mcg/kg/min', 2004),
#  ('mcg/ml', 1951),
#  ('mg/kg/day.', 1939),
#  ('lopinavir/ritonavir', 1880),
#  ('mg/day)', 1827),
#  ('(ml/min)', 1774),
#  ('ml/min.', 1750),
#  ('ml/minute/1.73', 1724),
#  ('mg/day).', 1667),
#  ('atazanavir/ritonavir', 1666),
#  ('(mg/day)', 1632),
#  ('/', 1584),
#  ('/l', 1505),
#  ('mg/ml)', 1496),
#  ('mg/dl', 1450),
#  ('pharyngitis/tonsillitis', 1293),
#  ('mcg/kg', 1165),
#  ('mg/25', 1155),
#  ('ng/ml', 1057),
#  ('ml/min/1.73m', 907),
#  ('cells/mm', 891),
#  ('mg/kg)', 888),
#  ('ml/min),', 874),
#  ('mg/kg,', 858),
#  ('mcg/day', 858),
#  ('ml/minute', 836),
#  ('caregiver/family', 791),
#  ('mg/kg.', 786),
#  ('mg/ml.', 773),
#  ('(olanzapine/fluoxetine)', 762),
#  ('(mg/dl)', 761),
#  ('mg/325', 753),
#  ('ml/h', 743)]

# %% [markdown]
# Most of these represent units of measurement (e.g. 'mg/day'). However, some of them represent combinations of distinct concepts (e.g. 'caregiver/family', 'pharyngitis/tonsillitis'). Splitting on whitespace would treat these as a single token, which would add unnecessary noise to the corpus. Let's try splitting on whitespace AND on '/'.

# %% [markdown]
# # Split on Whitespace and '/'

# %%
def tokenize(text):
    pattern = re.compile(r'[\s/]')
    tokens = re.split(pattern, text)
    tokens = [t for t in tokens if t != '']
    return tokens

# %%
tokenize('mg/day foo bar')
# Out:
# ['mg', 'day', 'foo', 'bar']

# %%
pipeline = [str.lower, tokenize]

# %%
df['tokens_slash'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df.head()
# Out:
#        target                                               text  \
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...
#
#                                               tokens  \
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...
#
#                                         tokens_slash
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...

# %%
# create list of all tokens
all_tokens = []
df['tokens_slash'].apply(lambda x: all_tokens.extend(x))
print(len(all_tokens))
# Out:
# 24731152

# %%
token_counts = Counter(all_tokens)

# %%
types = token_counts.keys()

# %%
print("Splitting on whitespace and '/' yields {0} tokens and {1} types.".format(token_counts.total(), len(types)))
# Out:
# Splitting on whitespace and '/' yields 24731152 tokens and 61765 types.

# %%
token_counts.most_common(50)
# Out:
# [('the', 848509),
#  ('of', 767519),
#  ('to', 633353),
#  ('and', 586252),
#  ('mg', 484695),
#  ('in', 429172),
#  ('for', 368581),
#  ('a', 365248),
#  ('be', 332954),
#  ('or', 326739),
#  ('with', 314055),
#  ('dose', 313695),
#  ('is', 274114),
#  ('patients', 241135),
#  ('should', 200650),
#  ('dosage', 196154),
#  ('not', 180928),
#  ('2', 150602),
#  ('daily', 147979),
#  ('may', 143437),
#  ('as', 141395),
#  ('day', 138186),
#  ('tablets', 136256),
#  ('use', 120634),
#  ('at', 119566),
#  ('recommended', 115114),
#  ('(', 107198),
#  ('by', 98774),
#  ('on', 96176),
#  ('than', 91941),
#  ('every', 90597),
#  ('1', 89290),
#  ('treatment', 89117),
#  ('if', 88278),
#  ('kg', 87791),
#  ('once', 87694),
#  ('ml', 87559),
#  ('years', 86196),
#  ('hours', 84764),
#  ('administration', 82247),
#  ('12', 80974),
#  ('10', 79724),
#  ('doses', 76306),
#  ('after', 75997),
#  ('children', 75723),
#  ('are', 74851),
#  ('clinical', 74396),
#  ('4', 71014),
#  (')', 70238),
#  ('•', 68972)]

# %% [markdown]
# # Split on Whitespace and '-'

# %% [markdown]
# Some of the most common types also included '-'. Let's take a look at them.

# %%
{t: count for t, count in token_counts.items() if '-' in t}
# Out:
# {'adults-': 112,
#  'older-': 108,
#  '(one-half': 184,
#  'naproxen-containing': 202,
#  'long-term': 5254,
#  'anti-inflammatory': 817,
#  'solid-oral': 128,
#  'weight-based': 1215,
#  'one-half': 2485,
#  'non-interchangeability': 233,
#  '3-4': 1244,
#  '2-11:': 523,
#  'fda-approved': 209,
#  '(weight-adjusted': 2,
#  '-': 14993,
#  'non-cutaneous': 4,
#  '0-1,': 26,
#  'half-life': 2096,
#  'radio-isotope': 25,
#  'thyroid-pituitary': 50,
#  '26-ml': 11,
#  'back-and-forth': 58,
#  '24-hour': 4566,
#  'high-potency': 19,
#  'hypothalamic-pituitary-adrenal': 379,
#  '2-3': 1166,
#  'angiotensin-converting': 1,
#  'twice-daily.': 2,
#  'film-coated': 197,
#  'ora-plus': 493,
#  'ora-sweet': 773,
#  'press-in': 12,
#  '(child-pugh': 3215,
#  '5-10': 473,
#  '1-5': 542,
#  'well-controlled': 462,
#  'end-stage': 918,
#  'pre-': 132,
#  'high-pressure': 50,
#  '(mria-sp).': 5,
#  'cyclosporine-therapeutic': 5,
#  '50-200': 78,
#  '50-150': 11,
#  'obsessive-compulsive': 51,
#  '6-12)': 35,
#  '13-17).': 11,
#  '25-200': 11,
#  '(6-17': 11,
#  'non-intravenous': 1289,
#  '14-day': 1267,
#  '1-': 268,
#  '2-day': 65,
#  'short-': 116,
#  'long-acting': 433,
#  'beta-blockers.': 42,
#  'water-resistant': 659,
#  'long-sleeve': 1461,
#  '15-30': 158,
#  'a.m.-2': 583,
#  'long-sleeved': 2667,
#  'salt-losing': 26,
#  'short-acting': 376,
#  '-agonist': 78,
#  're-evaluated': 548,
#  'beta2-agonist': 4,
#  'otc-dosage': 78,
#  'adults~3-5': 93,
#  '2-12': 113,
#  '1-3': 759,
#  'extended-release': 28876,
#  'half-glassful': 41,
#  'per-kilogram': 68,
#  'alpha-fetoprotein': 7,
#  '5-aminolevulinate': 8,
#  '(pbg)-synthase': 8,
#  'tri-vite': 3,
#  'single-day': 268,
#  'high-dose': 447,
#  'community-acquired': 1438,
#  '(second-line': 339,
#  'non-gonococcal': 343,
#  '(5-day': 298,
#  '3-day': 273,
#  '1-day': 447,
#  '(3-day': 154,
#  '5-day': 260,
#  '(1-day': 149,
#  're-dosing': 182,
#  're-dosed': 179,
#  'once-a-day': 1439,
#  'placebo-controlled': 747,
#  'longer-term': 575,
#  'delayed-release': 11687,
#  '500-1,000': 7,
#  'once-daily': 1209,
#  '-1,125': 2,
#  '1,250-1,375': 13,
#  '1,500-1,625': 13,
#  '1,875-2,000': 13,
#  '2,125-2,250': 13,
#  '2,500-2,750': 13,
#  '3,000-3,125': 13,
#  'dose-related': 456,
#  'dose-related.': 376,
#  '-to': 1,
#  'estrogen-containing': 1857,
#  'life-threatening': 1715,
#  'half-lives,': 253,
#  'dose-escalation': 253,
#  '2-fold': 309,
#  '(pill-free': 119,
#  'pill-free': 238,
#  '2-week': 772,
#  '2-fold,': 129,
#  'progestin-only': 171,
#  're-evaluation': 171,
#  'step-wise': 280,
#  'age-groups,': 102,
#  '2-': 90,
#  '5-mg': 605,
#  'enzyme-inducing': 237,
#  '4-week': 268,
#  'drug-induced': 326,
#  'blood-glucose-lowering': 120,
#  'anti-diabetic': 67,
#  'around-the-clock': 283,
#  '(single-': 99,
#  'multiple-dose)': 97,
#  'multiple-dose': 431,
#  'single-dose': 1939,
#  '10-15': 431,
#  'atropine-like': 141,
#  'low-dose': 345,
#  'opioid-naïve': 130,
#  'non-tolerant': 180,
#  '24-hr': 98,
#  'physically-dependent': 339,
#  '24-72': 341,
#  'community-based': 588,
#  'immediate-release': 1853,
#  'opioid-related': 1597,
#  'drug-seeking': 634,
#  'opioid-dependent': 587,
#  'follow-up': 1231,
#  'evidence-based': 718,
#  'co-morbid': 481,
#  'patient-specific': 751,
#  'opioid-dependent,': 619,
#  'dose-lowering': 531,
#  'β-hemolytic': 271,
#  'near-normal': 96,
#  'mg-tablet.': 34,
#  'flare-up': 754,
#  '1-10': 531,
#  'well-ventilated': 391,
#  'fixed-dose': 484,
#  'dose-limiting': 171,
#  'hiv-1-infected': 189,
#  'six-': 4,
#  'eight-hour': 85,
#  'pituitary-adrenal': 333,
#  're-establishment': 289,
#  'off-steroid': 650,
#  're-instituted.': 239,
#  'benefit-risk': 343,
#  '21-day': 479,
#  'free-flowing': 21,
#  'peri-venous': 4,
#  '241(23):2,530-2,533.': 7,
#  '8-aminoquinoline': 47,
#  '80-mg': 608,
#  'statin-based': 28,
#  'drug-drug': 265,
#  'ldl-c': 1863,
#  '40-mg': 158,
#  'ldl-c-lowering': 223,
#  'lipid-lowering': 925,
#  'one-day': 379,
#  'seven-day': 492,
#  're-treatment.': 119,
#  're-titration': 61,
#  'dose-response': 524,
#  'extented-release': 9,
#  '30-45': 71,
#  'intra-arterial': 467,
#  're-evaluate': 1073,
#  'steady-state': 1529,
#  'short-term,': 132,
#  'selection-oral': 21,
#  'flexible-dose': 317,
#  '(non-digitalized': 23,
#  'alpha-agonists,': 34,
#  'nucleoside-inhibitor-treatment-naïve': 51,
#  'lamivudine-experienced': 33,
#  'lamivudine-refractory': 39,
#  'treatment-naïve': 127,
#  'maxalt-mlt': 3,
#  'co-administered': 1400,
#  '10-mg': 458,
#  '30-day': 168,
#  'propranolol-treated': 50,
#  'tramadol-containing': 83,
#  '3-week': 97,
#  '7-day': 184,
#  '1-hour': 162,
#  '1-week': 98,
#  'pre-medication,': 24,
#  'coumarin-derivative': 24,
#  '-1st': 63,
#  '-2nd': 42,
#  '-3rd': 42,
#  '-4th': 21,
#  'hand-and-foot': 48,
#  'two-week': 202,
#  'thiazide-type': 132,
#  'one-': 118,
#  'beta-blockers': 274,
#  'post-myocardial': 463,
#  '(one-': 9,
#  'back-titrated': 22,
#  'flare-ups': 205,
#  'first-degree': 66,
#  '7-': 105,
#  '24-35': 520,
#  '36-47': 464,
#  '4-5': 601,
#  '48-59': 433,
#  '6-8': 1177,
#  '60-71': 434,
#  '9-10': 444,
#  '72-95': 436,
#  'acid-base': 308,
#  'intra-abdominal),': 23,
#  'non-narcotic': 49,
#  'asa-ps': 424,
#  'well-studied': 20,
#  'half-hour': 65,
#  'ready-to-use': 140,
#  'y-type': 69,
#  'in-line': 260,
#  'self-administration': 55,
#  'single-patient': 45,
#  'build-up': 60,
#  'infusion-related': 337,
#  'age-specific': 47,
#  '-m': 79,
#  'beta-lactam': 70,
#  'antibiotic-associated': 42,
#  'renally-impaired': 513,
#  'nsaid-associated': 206,
#  'zollinger-ellison': 842,
#  'catheter-tipped': 139,
#  'p-gp': 352,
#  'ldl-cholesterol': 69,
#  'hmg-coa': 391,
#  '20-mg': 72,
#  '6-month': 306,
#  '3-month': 171,
#  '8-week': 320,
#  'well-fitting,': 412,
#  '(pea-size)': 1,
#  '4-6': 781,
#  'soybean-based': 220,
#  'non-elderly': 541,
#  'free-t4': 1374,
#  '(l-thyroxine)': 48,
#  '(0-3': 220,
#  '0-3': 149,
#  '3-6': 203,
#  '6-12': 485,
#  'one-fourth': 733,
#  'pre-existing': 548,
#  'trimester-specific': 874,
#  'pre-pregnancy': 326,
#  'well-differentiated': 361,
#  'high-risk': 471,
#  'free-t4.': 268,
#  'pituitary-thyroid': 293,
#  'short-term': 1517,
#  'non-erosive': 107,
#  '2-4': 665,
#  '50-100': 75,
#  '--': 759,
#  '5-7': 169,
#  '6-16,': 16,
#  '80-320': 20,
#  '6-16': 43,
#  '1-4mg': 1,
#  '40-160': 32,
#  '20-160': 25,
#  'milligram-per-milligram': 137,
#  'child-resistant': 401,
#  'screw-cap': 128,
#  '*ora-sweet': 61,
#  'volume-depleted.': 63,
#  'beta-blockers,': 219,
#  '3-5': 182,
#  'hiv-1': 1117,
#  'low-strength': 24,
#  'pre-exposure': 34,
#  'hiv-uninfected': 54,
#  'two-drug': 34,
#  're-assess': 48,
#  're-': 4,
#  'one-month': 138,
#  '12-17': 50,
#  '6-11': 235,
#  '18-23': 42,
#  '12-23': 42,
#  '1-2': 811,
#  '8-': 264,
#  '12-hour': 507,
#  'sugar-free': 69,
#  'age-appropriate': 87,
#  'post-exposure': 295,
#  'pre-exposure)': 134,
#  '(>60-90': 45,
#  '(>30-60': 45,
#  '(>10-30': 45,
#  'fda-approved,': 57,
#  '10-day': 72,
#  'ora-sweet®': 104,
#  '(sugar-free)': 56,
#  'opioid-free': 55,
#  'non-opioid': 306,
#  'compliance-enhancing': 38,
#  'non-agonist': 17,
#  'portal-systemic': 18,
#  'single-daily': 148,
#  'anti-manic': 74,
#  '(10-15': 50,
#  'co-administration': 1461,
#  'chemotherapy-naïve:': 14,
#  'node-positive': 49,
#  'g-csf': 208,
#  'non-small': 200,
#  'platinum-based': 127,
#  'treatment-related': 112,
#  'chemotherapy-naïve': 38,
#  'castration-resistant': 131,
#  '30-minute': 219,
#  'non-hematological': 100,
#  'non-hematologic': 512,
#  'nci-ctcae': 30,
#  'plantar-palmar': 36,
#  '(di-2-ethylhexyl': 37,
#  'polyethylene-lined': 51,
#  'semi-logarithmic': 2,
#  '1-8': 32,
#  'broad-spectrum': 318,
#  '10am-2pm': 104,
#  'non-sterile.': 3,
#  'non-sterile': 11,
#  'post-implant': 11,
#  'dose-titration': 19,
#  'anti-spasmotics': 3,
#  'beta-blocking': 4,
#  '1-16': 48,
#  '36-48': 12,
#  'glucocorticoid-induced': 85,
#  're-treatment': 169,
#  'six-month': 33,
#  'post-treatment': 115,
#  '(6-8': 18,
#  'home-bound,': 31,
#  '25-hydroxyvitamin': 70,
#  'once-weekly': 53,
#  'gram-positive': 71,
#  '2-minute': 197,
#  'un-chewed': 81,
#  '-pull': 1,
#  '-clean': 9,
#  '-reseal': 2,
#  'broad-': 5,
#  'next-day': 73,
#  'cns-depressant': 77,
#  'epididymo-orchitis': 463,
#  '(post-exposure)': 969,
#  'well-tolerated.': 20,
#  'well-tolerated,': 54,
#  're-initiation': 347,
#  're-initiate': 56,
#  'co-medications': 25,
#  'co-medication': 77,
#  'inter-patient': 582,
#  'dose-dependent': 1139,
#  'dose-independent': 417,
#  'blood-pressure': 76,
#  'potassium-sparing': 268,
#  '300-mg-per-day': 21,
#  'non-pharmacological': 375,
#  'intra-thoracic': 17,
#  'intra-abdominal': 519,
#  '6-': 129,
#  '8-hour': 331,
#  'post-dose': 141,
#  'post-dose,': 125,
#  'semi-solid': 77,
#  '5-ml': 67,
#  're-suspend': 8,
#  '9-10.': 2,
#  'nityr-applesauce': 2,
#  '20-30': 302,
#  'mg-per-mg': 158,
#  'added-on': 18,
#  '20-25': 55,
#  '(68-77': 54,
#  'partial-onset': 949,
#  'on-going': 198,
#  '4-hour': 460,
#  '4-': 146,
#  '5-hour': 12,
#  'cross-sensitivity': 36,
#  '1-800-525-8747': 1,
#  '1-800-fda-1088': 58,
#  'non-black': 9,
#  'twice-daily': 874,
#  'left-ventricular': 10,
#  '(child-': 11,
#  'y-site': 421,
#  'high-fat': 178,
#  'corticosteroid-responsive': 25,
#  'schizophrenia-adults': 222,
#  'schizophrenia-adolescents': 203,
#  'mania-': 338,
#  'depression-adults': 151,
#  'mg-50': 49,
#  'schizophrenia-': 140,
#  '400-800': 229,
#  'schizophrenia-maintenance': 109,
#  '400-600': 82,
#  'depression-': 56,
#  'therapy-': 87,
#  'co-medicated': 153,
#  '6-fold': 112,
#  '5-fold': 128,
#  '7-14': 251,
#  'one-week,': 208,
#  're-initiated.': 135,
#  '6-mg': 26,
#  'l-a': 2,
#  '---': 174,
#  '(6-16': 12,
#  '1.3-2.7': 11,
#  '(2-8°c': 3,
#  '35-46°f)': 2,
#  'pre-treatment': 176,
#  '15-20': 94,
#  '3-times-daily': 40,
#  'beta-blocker': 364,
#  'alpha-adrenergic': 230,
#  'tablets-associated': 32,
#  'tablets-': 2,
#  'lennox-gastaut': 365,
#  '600-mg': 18,
#  'one-third': 296,
#  're-prime': 18,
#  '24-hours': 47,
#  'sustained-release': 326,
#  'mg-for-mg': 32,
#  'three-': 35,
#  'hormone-releasing': 33,
#  'counter-clockwise': 55,
#  '(luer-lok)': 26,
#  '(luer-lok).': 27,
#  '(1-2': 86,
#  'single-finger': 23,
#  'non-toxic': 24,
#  'non-pyrogenic.': 57,
#  'six-day': 38,
#  'carbidopa-levodopa,': 89,
#  '1-844-740-7500.': 7,
#  'west-ward)': 6,
#  '4-fold': 32,
#  'fold-volume': 2,
#  'digoxin-like': 37,
#  '10-25%': 15,
#  '4-minute': 17,
#  '(step-wise': 26,
#  'heart-rate': 17,
#  'rate-lowering': 26,
#  '(250-300': 9,
#  'hand-held': 56,
#  'calcium-containing': 480,
#  'y-site.': 89,
#  'ano-genital': 42,
#  '3-hour': 90,
#  'needle-stick': 94,
#  'opioid-': 31,
#  'co-infusion': 18,
#  'co-infusions': 17,
#  '6-,': 5,
#  '8-,': 5,
#  'imipenem-cilastatin': 5,
#  'fine-tooth': 51,
#  'throw-away': 57,
#  'x-ray,': 34,
#  '9-11': 150,
#  '(60-95': 149,
#  '(48-59': 155,
#  '2-5': 290,
#  'pari-lc-plus™': 17,
#  '(pre-dosing)': 76,
#  'ora-plus®*': 55,
#  'ora-sweet®*': 42,
#  '*ora-plus®': 38,
#  'infusion-associated': 28,
#  're-escalate': 7,
#  'protein-binding': 14,
#  'dehp-free': 7,
#  'half-tablet,': 174,
#  'half-tablet': 174,
#  'half-tablets': 153,
#  'add-on': 235,
#  '(0.85)(140-age)(weight)': 4,
#  '(140-age)(weight)': 4,
#  'post-hemodialysis': 650,
#  '900-3600': 9,
#  '30-59': 18,
#  '400-1400': 9,
#  '15-29': 26,
#  '200-700': 9,
#  '100-300': 9,
#  'exercise-induced': 206,
#  'air-dry': 45,
#  'pre-mixed': 19,
#  'two-port': 11,
#  're-evaluation.': 177,
#  'varicella-zoster': 186,
#  '6-hour': 343,
#  '800-mg': 74,
#  '200-mg': 117,
#  '500-mg': 158,
#  '875-mg': 150,
#  '250-mg': 185,
#  'tamper-evident': 72,
#  'cholesterol-lowering': 276,
#  'lipid-altering': 102,
#  'bile-acid-binding': 104,
#  '1.26-1.37': 9,
#  '1.38-1.51': 9,
#  '1.52-1.65': 9,
#  '1.66-1.77': 9,
#  '1.78-1.91': 9,
#  '1.92-2.05': 9,
#  '2.06-2.17': 9,
#  '0-1': 64,
#  '0-1;': 24,
#  're-evaluated.': 59,
#  'pre-prepared': 44,
#  'salt-depleted': 45,
#  'deeply-connecting': 6,
#  'only-fatal': 1,
#  'l-asparaginase,': 1,
#  'l-asparaginase': 4,
#  '5-ht': 329,
#  'in-office': 157,
#  '0.15-mg': 34,
#  'first-day': 66,
#  '15-minute': 209,
#  'opioid-containing': 86,
#  'fixed-ratio': 108,
#  'hepatically-impaired,': 5,
#  '5-days': 25,
#  'breast-feeding;': 25,
#  'breast-feeding,': 31,
#  'hla-b*5701': 72,
#  'copper-free': 14,
#  'ceruloplasmin-copper.': 11,
#  'protein-free': 18,
#  'self-limited': 117,
#  'non-steroidal': 157,
#  'anti-anxiety': 53,
#  'nucleoside\xadinhibitor-treatment-naïve': 1,
#  'treatment-na': 1,
#  'second-': 75,
#  'third-degree': 80,
#  'cns-acting': 106,
#  '20°-25°c(68°-77°f)': 1,
#  '1-800-222-1087': 2,
#  'p-glycoprotein': 77,
#  '(p-gp)': 73,
#  'tsc-associated': 53,
#  '5-15': 75,
#  'receptor-positive,': 12,
#  'her2-negative': 11,
#  '(tsc)-associated': 20,
#  'p-gp,': 6,
#  'p-glycoprotein.': 5,
#  'non-infectious': 31,
#  '70-kg': 152,
#  'low-birth': 19,
#  '5-phosphate': 6,
#  '-pantothenyl': 6,
#  '-α-tocopheryl': 5,
#  'thirty-three': 3,
#  'pea-sized': 398,
#  'medi-hands': 2,
#  'tonic-clonic': 826,
#  '7-8': 86,
#  'vancomycin-resistant': 63,
#  'pre-term': 73,
#  'full-term': 215,
#  'sub-optimal': 33,
#  '5-11': 14,
#  'mild-to-moderate': 479,
#  'ora-plus™': 92,
#  'sunday-start': 53,
#  'day-1': 54,
#  'self-adhesive': 20,
#  'on-1': 3,
#  '21-tablet': 23,
#  'on-7': 5,
#  '40-100': 138,
#  'binge-eating': 150,
#  're-examine': 320,
#  '(10-17': 69,
#  '(fixed-dose': 125,
#  'non-smoking': 129,
#  're-inserting': 1,
#  '40-80': 59,
#  'mg-80': 40,
#  're-epithelialisation': 13,
#  '2-5)': 9,
#  '6-11)': 9,
#  '24-47': 16,
#  '48-95': 43,
#  '24-': 44,
#  're-initiated)': 12,
#  'potassium-depleting': 11,
#  '(140-age)': 103,
#  'in-hospital': 35,
#  'half-lives.': 13,
#  'preservative-free': 386,
#  'anticoagulant-induced': 48,
#  '15-g': 20,
#  'neuro-psychiatric': 72,
#  'intra-articular': 584,
#  '20-': 17,
#  '24-gauge': 12,
#  '1.0-2.0': 4,
#  '0.5-1.0': 36,
#  '0.25-0.5': 4,
#  '25-gauge,': 24,
#  '½-inch': 14,
#  '¾-inch': 2,
#  'emete-con': 36,
#  'levo-dromoran': 37,
#  'histamine-mediated': 180,
#  '8-week,': 109,
#  'acute-treatment': 114,
#  'open-label': 80,
#  'double-blind': 49,
#  '[140-age': 123,
#  '-------------------------------------------------------------------------': 2,
#  '----------------------------': 13,
#  'opioid-tolerant.': 30,
#  'opioid-tolerant': 231,
#  '60-134': 48,
#  '135-224': 48,
#  '225-314': 48,
#  '315-404': 48,
#  '10-22': 24,
#  '23-37': 24,
#  '38-52': 24,
#  '53-67': 24,
#  '30-67': 24,
#  '67.5-112': 24,
#  '112.5-157': 24,
#  '157.5-202': 24,
#  '150-447': 24,
#  '8-17': 32,
#  '17.1-28': 24,
#  '28.1-39': 24,
#  '39.1-51': 24,
#  '1.5-3.4': 24,
#  '3.5-5.6': 24,
#  '5.7-7.9': 24,
#  '8-10': 157,
#  '75-165': 24,
#  '166-278': 24,
#  '279-390': 24,
#  '391-503': 24,
#  '20-44': 24,
#  '45-74': 24,
#  '75-104': 24,
#  '105-134': 24,
#  '405-494': 24,
#  '495-584': 24,
#  '585-674': 24,
#  '675-764': 24,
#  '765-854': 24,
#  '855-944': 24,
#  '945-1034': 24,
#  '1035-1124': 24,
#  '72-hour': 101,
#  'non-irritated,': 25,
#  'non-irradiated': 25,
#  'pre-measured': 23,
#  'intra-articular,': 101,
#  '89(3):495-501.': 92,
#  'bile-acid': 37,
#  '(50-100': 36,
#  'extended-release,': 82,
#  'up-titration.': 543,
#  'extended-release.': 183,
#  'ceteareth-20,': 2,
#  'peg-100': 5,
#  'x-ray': 105,
#  '1-800-828-9393': 4,
#  'iop-lowering': 2,
#  'sulfonylurea-class': 144,
#  'non-insulin-': 14,
#  '(3-4': 27,
#  'blister-packaged': 6,
#  'pre-filled': 119,
#  'self-injection': 54,
#  'non-leukemia': 28,
#  'c-kit': 93,
#  'fip1l1-pdgfrα,': 25,
#  'fip1l1-pdgfrα': 53,
#  'platelet-derived': 10,
#  'desensitization-': 2,
#  '-ask': 1,
#  'polyglyceryl-10': 6,
#  'peg-12': 6,
#  'steareth-20,': 6,
#  'c13-14': 7,
#  'laureth-7,': 7,
#  '8-12': 225,
#  '0.5-1': 20,
#  '7-10': 60,
#  '-r': 33,
#  '-r,': 9,
#  '(post-exposure):': 175,
#  'mania-children': 51,
#  'therapy-adults': 23,
#  'tobramycin-spl-figure': 2,
#  'calcium-based': 26,
#  '-initially,': 14,
#  'longer-acting': 25,
#  'within-day': 13,
#  'beta-adrenergic': 98,
#  'up-titration': 143,
#  'β-blocker': 126,
#  '24-mg': 31,
#  '8-mg': 146,
#  '4-mg': 256,
#  'thallium-201': 37,
#  'a.m.-2p.m.': 32,
#  'chemotherapy-induced': 79,
#  '20-25°c': 131,
#  '(68-77°f)': 117,
#  'non-dialysis': 130,
#  'full-dose': 151,
#  'weight-adjusted': 61,
#  'anti-factor': 99,
#  'open-heart': 98,
#  '26-gauge)': 41,
#  'gabapentin-equation': 37,
#  'mania-adults': 25,
#  'cockcroft-gault-equation.jpg': 1,
#  '-------------------------------------------------------------': 5,
#  '----------------------------------------------(x': 16,
#  '--------------------------': 19,
#  '----': 79,
#  'ceftriaxone-calcium': 107,
#  'normosol-m': 46,
#  'ionosol-b': 42,
#  '(-20°c)': 42,
#  'one-week': 167,
#  'super-': 13,
#  'non-vented': 34,
#  'di-2-ethylhexyl': 14,
#  'angle-closure': 76,
#  'open-angle': 49,
#  'angle-closure,': 22,
#  'extended-': 80,
#  'acid-mediated': 761,
#  '200-400': 13,
#  'alpha-blockers': 192,
#  'alpha-blocker': 472,
#  'cockcroft-gault': 431,
#  'non-squamous': 133,
#  'first-line': 69,
#  '0-2,': 21,
#  '100-mg': 187,
#  '(preservative-free)': 84,
#  'green-yellow.': 20,
#  '[2-8°c': 28,
#  '(36-46°f)]': 24,
#  'starch-based': 24,
#  '------------------------------------------------------': 12,
#  'dose-reductions': 21,
#  'ckd-epi,': 62,
#  'non-transfusion-dependent': 80,
#  'fda-cleared': 36,
#  '1-month': 65,
#  'aluminum-containing': 33,
#  'transfusion-dependent': 22,
#  'nephrotoxic-therapies': 6,
#  '-17': 34,
#  'udp-glucuronosyltransferases': 32,
#  'non-emergent': 48,
#  'non-emergency': 21,
#  'large-gauge': 12,
#  'dextrose-containing': 56,
#  "'fluid-air": 2,
#  'air-fluid': 1,
#  'take1-2': 5,
#  'tablet-free': 3,
#  'back-up': 139,
#  '28-day': 560,
#  'second-trimester': 20,
#  'tablet-taking.': 3,
#  'first-trimester': 18,
#  'three-drug': 39,
#  'short-course': 40,
#  '4-ounce': 19,
#  'above-mentioned': 10,
#  'pressure-lowering': 26,
#  '68°-77°f': 2,
#  '20°-': 5,
#  'high-intensity': 50,
#  '2-inch': 72,
#  'circulatory-': 1,
#  'allergic-': 1,
#  'stevens-johnson': 16,
#  'other-': 1,
#  '(single-dose': 15,
#  'mu-opioid': 29,
#  'long-': 75,
#  'methadone-maintained': 21,
#  'take-home': 111,
#  'once-monthly': 76,
#  'recovery-oriented': 56,
#  'medication-assisted': 57,
#  '(hiv-1': 18,
#  'lead-in': 179,
#  'every-2-month': 10,
#  'sub-therapeutic': 24,
#  'caffeine-like': 20,
#  'steady-state.': 48,
#  '-adrenergic': 7,
#  '2-7': 5,
#  '9-14': 2,
#  '16-21': 2,
#  '23-28': 2,
#  '1.5-3': 25,
#  '(sanofi-aventis': 11,
#  'syrups-simple': 8,
#  'non-induced': 30,
#  'non-enzyme-inducing': 6,
#  're-usable.': 59,
#  'once-daily.': 96,
#  'mg-3200': 57,
#  'well-controlledclinical': 36,
#  'delayed-': 28,
#  'androgen-deficient': 4,
#  'one-sixth': 15,
#  'glucose-containing': 78,
#  '1-year': 93,
#  '5-year': 103,
#  '10-year': 93,
#  '15-year': 93,
#  '------------------------------------------------': 26,
#  '--------------------------------': 16,
#  'two-minute': 33,
#  'thyroid-stimulating': 21,
#  'clip-lid': 3,
#  'fresh-seal': 3,
#  '(34-47': 25,
#  'metformin-associated': 16,
#  '-limit': 53,
#  '-1': 104,
#  '-2': 158,
#  '-3': 47,
#  '-4': 8,
#  'in-hospital.': 35,
#  'age-adjusted': 35,
#  'half-lives': 157,
#  '6-ounce': 35,
#  'water-insoluble': 31,
#  '(20°-25°c': 3,
#  '68°-77°f)': 2,
#  'two-years': 210,
#  'acid-stable': 40,
#  'beta-hemolytic': 146,
#  '15-21': 8,
#  'injection-related': 69,
#  'risk-benefit': 207,
#  'dose-intense': 25,
#  '(life-threatening': 28,
#  '300-mg': 148,
#  '(immediate-release),': 73,
#  '(child-pugh=5': 78,
#  '(child-pugh=7': 78,
#  '(child-pugh=10': 78,
#  '-release': 8,
#  'around-the': 5,
#  '-clock': 3,
#  'renin-angiotensin': 31,
#  'cockcroft-gault)': 67,
#  '-or-': 56,
#  'impairment-do': 49,
#  '3-cm': 14,
#  'adams-stokes': 11,
#  'post-operative': 99,
#  '8-to': 10,
#  'ery-ped': 1,
#  'twice-a-day': 474,
#  '30-50': 44,
#  '15-25': 15,
#  '-xr': 53,
#  '-xr,': 6,
#  'age-initial': 72,
#  '10-20': 407,
#  '(12-15': 20,
#  'tegretol-xr': 20,
#  '59°-86°f': 4,
#  '(15°-30°c)': 3,
#  'break-up': 1,
#  'non-preserved': 2,
#  '185-370': 1,
#  '(5-10': 42,
#  'non-diabetic': 1,
#  '50-75': 19,
#  'non-ischemic': 1,
#  '30-100': 4,
#  '--------------------------------------------------------': 7,
#  '---------------------------------------': 8,
#  '-------------------': 5,
#  '15°-25°c': 2,
#  '(59°-77°f)': 2,
#  'drug-resistant': 29,
#  'sugar-coated': 2,
#  '5-': 86,
#  '2-8°c': 76,
#  '(36-46°f)': 74,
#  'age-related': 15,
#  'brownish-yellow': 7,
#  '5-micron': 22,
#  '18-gauge': 14,
#  '30-gauge': 23,
#  'flip-off': 78,
#  'alpha-naïve': 6,
#  '(hcv)-rna': 3,
#  'hcv-rna': 30,
#  're-treated': 3,
#  '66-80': 2,
#  '81-105': 1,
#  '3-17': 2,
#  '47-59': 1,
#  '60-73': 1,
#  'two-step': 17,
#  'four-week': 14,
#  'interferon-alfa-naïve': 3,
#  '(3-17': 1,
#  'non-affected': 11,
#  'non-medicated': 29,
#  'super-high': 103,
#  '0-10': 449,
#  '10-25': 182,
#  '12-72': 23,
#  'bulk-forming': 17,
#  'once-a-week': 67,
#  'magnesium-based': 15,
#  'once-a-week,': 24,
#  '(75-mg': 10,
#  '325-mg)': 10,
#  '10-': 62,
#  'half-life,': 95,
#  'two-hour': 139,
#  'volume-contracted.': 41,
#  '1-minute': 105,
#  '(auto-injector)': 14,
#  'auto-injector': 128,
#  '-apply': 83,
#  '-children': 81,
#  'first-level': 5,
#  '(modified-release,': 18,
#  'timed-release)': 18,
#  'adult-equivalent': 30,
#  'estrogen-alone': 8,
#  'dilantin-125': 11,
#  'self-help': 37,
#  'non-psychotic': 109,
#  'on-treatment': 40,
#  'twice-a-day.': 204,
#  'twice-a-day);': 41,
#  'twice-a-day,': 41,
#  'twice-a-day)': 41,
#  'ml-2.5': 3,
#  'mg-100': 3,
#  'ml-3.4': 3,
#  'mg-136': 3,
#  'ml-5.1': 3,
#  'mg-204': 3,
#  '4-16': 38,
#  'co-formulated': 13,
#  ...}

# %% [markdown]
# In contrast to words combined with '/', these combined with '-' tend to represent a single concept. Splitting them into separate tokens would lose important information (e.g. 'non-psychotic').

# %% [markdown]
# # Final Tokenization

# %% [markdown]
# Based on the above analysis, we will split on whitespace and '/', and remove punctuation.

# %%
punct_set = set(punctuation)
punct_set.remove('/') # don't remove '/' because we need it for tokenization

# %%
def remove_punctuation(text):
    return "".join([char for char in text if char not in punct_set])

# %%
pipeline = [str.lower, remove_punctuation, tokenize]

# %%
prepare('This is an example/test sentence!', pipeline=pipeline)
# Out:
# ['this', 'is', 'an', 'example', 'test', 'sentence']

# %%
df['tokens_final'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df.head()
# Out:
#        target                                               text  \
# 0        ORAL  DOSAGE Adults- Take 4 or 6 Pellets by mouth, t...
# 1        ORAL  DIRECTIONS Adults: Dissolve 3 to 5 under the t...
# 2  OPHTHALMIC  DOSAGE AND ADMINISTRATION The recommended dosa...
# 3        ORAL  2 DOSAGE AND ADMINISTRATION Use the lowest eff...
# 4     TOPICAL  Directions wet face, apply to hand, massage fa...
#
#                                               tokens  \
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...
#
#                                         tokens_slash  \
# 0  [dosage, adults-, take, 4, or, 6, pellets, by,...
# 1  [directions, adults:, dissolve, 3, to, 5, unde...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face,, apply, to, hand,, mas...
#
#                                         tokens_final
# 0  [dosage, adults, take, 4, or, 6, pellets, by, ...
# 1  [directions, adults, dissolve, 3, to, 5, under...
# 2  [dosage, and, administration, the, recommended...
# 3  [2, dosage, and, administration, use, the, low...
# 4  [directions, wet, face, apply, to, hand, massa...

# %%
# create list of all tokens
all_tokens = []
df['tokens_final'].apply(lambda x: all_tokens.extend(x))
print(len(all_tokens))
# Out:
# 24731152

# %%
token_counts = Counter(all_tokens)

# %%
types = token_counts.keys()

# %%
print("Splitting on whitespace and '/' and removing punctuation yields {0} tokens and {1} types.".format(token_counts.total(), len(types)))
# Out:
# Splitting on whitespace and '/' and removing punctuation yields 24731152 tokens and 34108 types.

# %%
token_counts.most_common(50)
# Out:
# [('the', 848938),
#  ('of', 768502),
#  ('to', 635549),
#  ('and', 587906),
#  ('mg', 523998),
#  ('in', 430655),
#  ('', 426939),
#  ('for', 371221),
#  ('a', 368349),
#  ('dose', 355718),
#  ('be', 332983),
#  ('or', 330966),
#  ('with', 315488),
#  ('is', 275316),
#  ('patients', 274922),
#  ('dosage', 206659),
#  ('daily', 205683),
#  ('day', 203796),
#  ('should', 202188),
#  ('not', 182203),
#  ('2', 171258),
#  ('tablets', 162035),
#  ('may', 143986),
#  ('as', 142470),
#  ('use', 132080),
#  ('recommended', 127337),
#  ('at', 120059),
#  ('1', 115875),
#  ('hours', 114164),
#  ('see', 113131),
#  ('ml', 109633),
#  ('treatment', 104055),
#  ('kg', 100482),
#  ('by', 99287),
#  ('years', 98070),
#  ('on', 96324),
#  ('administration', 95210),
#  ('doses', 95075),
#  ('every', 92464),
#  ('than', 91943),
#  ('if', 90163),
#  ('once', 88880),
#  ('10', 88818),
#  ('12', 87342),
#  ('children', 84313),
#  ('5', 81334),
#  ('4', 78610),
#  ('therapy', 77186),
#  ('after', 76517),
#  ('are', 75080)]
